# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import pickle
from tkinter import *
import tkinter as tk

from flask import Flask,request,jsonify
import pymongo
from sklearn.manifold import TSNE
from tkinter import PhotoImage
from PIL import Image, ImageTk
model=pickle.load(open('model.pkl','rb'))

# %%
from flask import Flask
client=pymongo.MongoClient("mongodb+srv://satwikit21051:Satwik2021@cluster0.y20y4y1.mongodb.net/?retryWrites=true&w=majority")
db=client.test
db=client['prediction']
col=db["table"]
app = Flask(__name__)

@app.route('/milk', methods=['GET','POST'])
def satwik():
        def predict():
                    A=float(e1.get())
                    B=float(e2.get())
                    C=float(e3.get())
                    D=float(e4.get())
                    E=float(e5.get())
                    F=float(e6.get())
                    a=[[A,B,C,D,E,F]]
                    d=pd.DataFrame(a)
                    

                    
                    prediction = str(model.predict(d))  
                    dict = {
                         'pH':A,
                         'Temprature':B,
                         'Taste':C,
                         'Odor':D,
                         'Turbidity':E,
                         'Colour':F,
                         'Grade':prediction
                    
                     }
                    col.insert_one(dict)
                    display.insert(0,str(prediction))
             
        def clear():
                    e1.delete(0, END)
                    e2.delete(0, END)
                    e3.delete(0, END)
                    e4.delete(0, END)
                    e5.delete(0, END)
                    e6.delete(0, END)
                    
                    display.delete(0, END)
        def delt():
                    col.delete_many({})
        root = Tk()
        root.geometry('400x200+100+200')
        
        original_image = Image.open("cow.png") 
        width, height = 400, 300  
        resized_image = original_image.resize((width, height), Image.ANTIALIAS)
        photo = ImageTk.PhotoImage(resized_image)
        background_label = Label(root, image=photo)
        background_label.place(x=860, y=180, width=width, height=height)
        
        l1 = Label(root, text="pH-------------------------",  font="Arial 11 bold")
        sat = Label(root, text="By Satwik Tiwari",  font="Arial 9 bold")
        l2 = Label(root, text="Temprature-----------------",font="Arial 11 bold")
        l3 = Label(root, text="Taste----------------------",  font="Arial 11 bold")
        l4 = Label(root, text="Odor(smell)-----------------------", font="Arial 11 bold")
        l5 = Label(root, text="Turbidity------------------", font="Arial 11 bold")
        l6 = Label(root, text="Colour---------------------", font="Arial 11 bold")
       
        
        l1.pack()
        
        #l = Label(root, text="Prediction Of Cement Strength Using Machine Learning",bg="gray" , font="Arial 30 bold")
        lb1=Label(root, text="1.ph-> the pH value of fresh milk should lie between 6.6 - 6.8. A higher pH value indicates a mastitis infection in the cow and a pH of below 6.5 indicates towards acidification of the sample. ")
        lb2=Label(root, text="2.Temprature-> Milk temperature thresholds of >38.7°C or ≥39.0°C should be used to identify cows with fever at each milking event or for any time of day")
        lb3=Label(root, text="3.Taste-> The chloride-lactose relation is one of the most important bases of milk taste.")
        lb4=Label(root, text="4.Odor-> A cowy or acetone smell may indicate a metabolic disorder.")
        lb5=Label(root, text="5.Turbidity->Turbidity in milk is generally considered undesirable, and in most cases, it is a sign of poor milk quality.")
        lb6=Label(root, text="6.Colour-> Milk is naturally a white substance due to the make-up of water")
        lb1.place(x=150,y=10)
        lb2.place(x=150,y=40)
        lb3.place(x=150,y=70)
        lb4.place(x=150,y=100)
        lb5.place(x=150,y=130)
        lb6.place(x=150,y=160)
        
        sat.place(x=0,y=0)
        b1=Button(root,text="predict(in MPa)",font="Arial 13 bold",bg="orange",command=predict)
        b2=Button(root,text="clear",font="Arial 13 bold",bg="red",command=clear)
        b3=Button(root,text="Delete All from Database",font="Arial 13 bold",bg="Yellow",command=delt)

        l1.place(x=150,y=215)
        l2.place(x=150,y=235)
        l3.place(x=150,y=255)
        l4.place(x=150,y=275)
        l5.place(x=150,y=295)
        l6.place(x=150,y=315)
        
        b1.place(x=150,y=450)
        #l.place(x=130,y=60)

        e1=Entry(root,bg="pink",font="Arial 13 bold")
        e2=Entry(root,bg="pink",font="Arial 13 bold")
        e3=Entry(root,bg="pink",font="Arial 13 bold")
        e4=Entry(root,bg="pink",font="Arial 13 bold")
        e5=Entry(root,bg="pink",font="Arial 13 bold")
        e6=Entry(root,bg="pink",font="Arial 13 bold")
        
        display=Entry(root,font="Arial 13 bold")
        e1.place(x=600,y=215)
        e2.place(x=600,y=236)
        e3.place(x=600,y=257)
        e4.place(x=600,y=278)
        e5.place(x=600,y=299)
        e6.place(x=600,y=320)
        
        b2.place(x=800,y=450)
        b3.place(x=600,y=500)
        display.place(x=600,y=450)
        root.mainloop()
        return "hello...."
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# C:\Users\HP\AppData\Local\Temp\ipykernel_19932\33445774.py:52: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resized_image = original_image.resize((width, height), Image.ANTIALIAS)
# C:\Anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...
