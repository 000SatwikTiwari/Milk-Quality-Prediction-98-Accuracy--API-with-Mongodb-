# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import statistics as stat
from tkinter import *
import tkinter
from flask import Flask,request,jsonify
import pymongo
from pymongo import MongoClient
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("milknew.csv")
df
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0     6.6          35      1     0     1          0     254    high
# 1     6.6          36      0     1     0          1     253    high
# 2     8.5          70      1     1     1          1     246     low
# 3     9.5          34      1     1     0          1     255     low
# 4     6.6          37      0     0     0          0     255  medium
# ...   ...         ...    ...   ...   ...        ...     ...     ...
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low
#
# [1059 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# pH            0
# Temprature    0
# Taste         0
# Odor          0
# Fat           0
# Turbidity     0
# Colour        0
# Grade         0
# dtype: int64

# %%
x=df[["pH","Temprature","Taste","Odor","Turbidity","Colour"]]

# %%
y=df[["Grade"]]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.30, random_state =250) #to maximize the accuracy

# %%
logreg = LogisticRegression()
knn_classifier = KNeighborsClassifier(10)
nb=GaussianNB()
logreg.fit(xtrain, ytrain)
knn_classifier.fit(xtrain, ytrain)
nb.fit(xtrain, ytrain)
logreg_ypred = logreg.predict(xtest)
knn_classifier_ypred = knn_classifier.predict(xtest)
nb_ypred=nb.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

logreg_acc = accuracy_score(ytest, logreg_ypred)
knn_classifier_acc = accuracy_score(ytest, knn_classifier_ypred)
nb_acc = accuracy_score(ytest, nb_ypred)

# %%
print ("Logistic Regression accuracy : ", round(logreg_acc*100, 2))
print ("K-NN Classifier accuracy     : ", round(knn_classifier_acc*100, 2))
print ("Naive Biase accuracy       : ", round(nb_acc*100, 2))
# Out:
# Logistic Regression accuracy :  66.67
# K-NN Classifier accuracy     :  98.11
# Naive Biase accuracy       :  86.48

# %%
import pickle
pickle.dump(knn_classifier,open("model.pkl",'wb'))
pickled_model=pickle.load(open("model.pkl",'rb'))

# %%
knn_classifier_ypred
# Out:
# array(['low', 'medium', 'low', 'medium', 'medium', 'high', 'medium',
#        'medium', 'high', 'medium', 'medium', 'low', 'low', 'low',
#        'medium', 'high', 'medium', 'medium', 'low', 'low', 'medium',
#        'medium', 'low', 'medium', 'low', 'high', 'medium', 'high', 'low',
#        'medium', 'low', 'low', 'low', 'high', 'low', 'medium', 'medium',
#        'low', 'low', 'high', 'high', 'medium', 'high', 'high', 'low',
#        'low', 'medium', 'high', 'medium', 'medium', 'low', 'medium',
#        'low', 'medium', 'high', 'low', 'medium', 'medium', 'medium',
#        'medium', 'medium', 'low', 'low', 'low', 'low', 'high', 'high',
#        'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'low',
#        'low', 'low', 'medium', 'medium', 'medium', 'low', 'high', 'high',
#        'high', 'medium', 'medium', 'high', 'low', 'low', 'high', 'low',
#        'high', 'high', 'low', 'low', 'low', 'high', 'high', 'medium',
# ...

# %%
df
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0     6.6          35      1     0     1          0     254    high
# 1     6.6          36      0     1     0          1     253    high
# 2     8.5          70      1     1     1          1     246     low
# 3     9.5          34      1     1     0          1     255     low
# 4     6.6          37      0     0     0          0     255  medium
# ...   ...         ...    ...   ...   ...        ...     ...     ...
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low
#
# [1059 rows x 8 columns]

# %%
a=[[6.8,43,1,0,0,250]]
d=pd.DataFrame(a)
pickled_model.predict(d)
# Out:
# array(['high'], dtype=object)
